# %%
import numpy as np
import cv2
from skimage import metrics
from sklearn.feature_extraction import image
import matplotlib.pyplot as plt

# %% [markdown]
# upload data

# %%
# Étape 1 : Installer PyDrive pour interagir avec Google Drive
# !pip install -U PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
import os

# Étape 2 : Authentification
from google.colab import auth
auth.authenticate_user()

from oauth2client.client import GoogleCredentials
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Étape 3 : Télécharger le contenu du dossier
def download_folder(drive, folder_id, dest_path):
    """Télécharge tous les fichiers dans un dossier Google Drive public."""
    file_list = drive.ListFile({'q': f"'{folder_id}' in parents and trashed=false"}).GetList()
    if not os.path.exists(dest_path):
        os.makedirs(dest_path)
    for file in file_list:
        file_name = os.path.join(dest_path, file['title'])
        if file['mimeType'] == 'application/vnd.google-apps.folder':
            download_folder(drive, file['id'], file_name)  # Récursion pour sous-dossiers
        else:
            print(f"Téléchargement du fichier : {file['title']}")
            file.GetContentFile(file_name)

# Remplacer par l'ID du dossier partagé
folder_id = "1AN64B9rsSFGL1u8bUJzB9By_Np3fLZ1u"
dest_path = "./dataset"

download_folder(drive, folder_id, dest_path)

# Étape 4 : Vérifier les fichiers téléchargés
for root, dirs, files in os.walk(dest_path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.10/dist-packages (from PyDrive) (2.155.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.10/dist-packages (from PyDrive) (6.0.2)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (2.27.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (2.19.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (4.1.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (1.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (4.25.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (1.25.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=1.2->PyDrive) (5.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.2->PyDrive) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2024.12.14)
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive
# Téléchargement du fichier : 06901.png
# Téléchargement du fichier : 07102.png
# Téléchargement du fichier : 06801.png
# Téléchargement du fichier : 07201.png
# Téléchargement du fichier : 07002.png
# Téléchargement du fichier : 07101.png
# Téléchargement du fichier : 07001.png
# Téléchargement du fichier : 03602.png
# Téléchargement du fichier : 04501.png
# Téléchargement du fichier : 03503.png
# Téléchargement du fichier : 04101.png
# Téléchargement du fichier : 03802.png
# Téléchargement du fichier : 06402.png
# Téléchargement du fichier : 03902.png
# Téléchargement du fichier : 04201.png
# Téléchargement du fichier : 04002.png
# Téléchargement du fichier : 04401.png
# Téléchargement du fichier : 03901.png
# Téléchargement du fichier : 04102.png
# Téléchargement du fichier : 04001.png
# Téléchargement du fichier : 03702.png
# Téléchargement du fichier : 04202.png
# Téléchargement du fichier : 03502.png
# Téléchargement du fichier : 03601.png
# Téléchargement du fichier : 03904.png
# Téléchargement du fichier : 03903.png
# Téléchargement du fichier : 04301.png
# Téléchargement du fichier : 03603.png
# Téléchargement du fichier : 03801.png
# Téléchargement du fichier : 03701.png
# Téléchargement du fichier : 03203.png
# Téléchargement du fichier : 03001.png
# Téléchargement du fichier : 03102.png
# Téléchargement du fichier : 02804.png
# Téléchargement du fichier : 03301.png
# Téléchargement du fichier : 02905.png
# Téléchargement du fichier : 03101.png
# Téléchargement du fichier : 02701.png
# Téléchargement du fichier : 02801.png
# Téléchargement du fichier : 02802.png
# Téléchargement du fichier : 03002.png
# Téléchargement du fichier : 03401.png
# Téléchargement du fichier : 03003.png
# Téléchargement du fichier : 03302.png
# Téléchargement du fichier : 02901.png
# Téléchargement du fichier : 03403.png
# Téléchargement du fichier : 03201.png
# Téléchargement du fichier : 02803.png
# Téléchargement du fichier : 03202.png
# Téléchargement du fichier : 02902.png
# Téléchargement du fichier : 03501.png
# Téléchargement du fichier : 02904.png
# Téléchargement du fichier : 03004.png
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (256, 256))
        return img

    @staticmethod
    def extract_features(img):
        """Extract features like noise level and entropy."""
        noise_level = np.var(img)  # Variance as a proxy for noise
        entropy = shannon_entropy(img)
        return {
            "noise_level": noise_level,
            "entropy": entropy
        }


# Préparer les données
prepared_data = DataPreparation.preprocess_image("./dataset/images_inter/04501.png")
feature = DataPreparation.extract_features(prepared_data)
print(feature)
# Afficher l'image avec Matplotlib
plt.imshow(prepared_data, cmap="gray")  # Assurez-vous que l'image est en niveaux de gris
plt.title("Préprocessed Image")
plt.axis("off")
plt.show()
# Out:
# {'noise_level': 1264.783793296665, 'entropy': 7.064671721806573}

# %% [markdown]
# ---
# Filtrage, contrast, threashold

# %%
class Filtrage:
    #filtrage--------------------------------------
    def apply_Gaussien_filter(img, kernel_size,sigmaX):
        return cv2.GaussianBlur(img, (kernel_size, kernel_size), sigmaX)

    def apply_median_filter(img, kernel_size):
        return cv2.medianBlur(img, kernel_size)

    def apply_mean_filter(img, kernel_size):
        return cv2.blur(img, kernel_size)

class contrast:
    #contrast-------------------------------------
    def adjust_contrast_equalization(img):
      return cv2.equalizeHist(img)

    def adjust_contrast_clahe(img, clip_limit, tile_grid_size=(8, 8)):
        clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
        return clahe.apply(img)

class threashold:
    #threshold-----------------------------------
    def threshold_global(img, threshold):
      _, binary_img = cv2.threshold(img, threshold, 255, cv2.THRESH_BINARY)
      return binary_img

    def threshold_local(img, block_size, C):
      binary_img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, block_size, C)
      return binary_img

# %% [markdown]
# Segmentation

# %%
import cv2
import numpy as np

class Segmentation:
    @staticmethod
    def sobel(img, ksize, scale, delta, border_type=cv2.BORDER_DEFAULT):
        """
        Apply Sobel edge detection to the image.

        Parameters:
        - img: The input image
        - ksize: Kernel size
        - scale: Scale factor for the derivative
        - delta: Delta value added to the result
        - border_type: Border handling type (default is cv2.BORDER_DEFAULT)

        Returns:
        - Sobel magnitude (edges)
        """
        grad_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=ksize, scale=scale, delta=delta, borderType=border_type)
        grad_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=ksize, scale=scale, delta=delta, borderType=border_type)
        return cv2.magnitude(grad_x, grad_y)

    @staticmethod
    def canny(img, threshold1, threshold2, aperture_size, L2gradient=False):
        """
        Apply Canny edge detection to the image.

        Parameters:
        - img: The input image
        - threshold1: The first threshold for the hysteresis procedure
        - threshold2: The second threshold for the hysteresis procedure
        - aperture_size: Aperture size for the Sobel operator
        - L2gradient: Boolean to indicate whether to use the more accurate L2 gradient (default is False)

        Returns:
        - Binary image with edges detected
        """
        return cv2.Canny(img, threshold1, threshold2, apertureSize=aperture_size, L2gradient=L2gradient)

# %% [markdown]
# Parameters

# %%
kernel_size=[3, 5, 10]
sigmaX=[0.1,  1.0, 2.0]
block_size=[3, 7, 11]
C=[0.1, 1.0, 2.0]
threshold=[100, 127, 150]
clip_limit=[1,2, 5]
tile_grid_size=[(3, 3), (5, 5), (7, 7), (11, 11)]

ksize = [3, 5, 7]
scale = [1, 2, 3]
delta = [0, 1, 2]
threshold1 = [50, 100, 150]
threshold2 = [150, 200, 250]
aperture_size = [3, 5, 7]

# %%
action = [
    {"type": "filter", "method": "gaussian", "kernel_size": 3, "sigmaX": 0.1},
    {"type": "contrast", "method": "clahe", "clip_limit": 2.0, "tile_grid_size":(8, 8)},
    {"type": "threshold", "method": "global", "threshold": 127},
    {"type": "segmentation", "method": "sobel", "ksize": 3, "scale": 1, "delta": 0},
]

# %%
import numpy as np
import cv2

class QLearning:
    def __init__(self, kernel_size, sigmaX, block_size, C, threshold, clip_limit, tile_grid_size):
        # Initialize the Q-table (for simplicity, use a dictionary of Q-values)
        self.Q_table = {}
        self.actions = {
            'filter': ['Gaussien', 'Median', 'Mean'],
            'contrast': ['Equalization', 'CLAHE'],
            'threshold': ['Global', 'Local']
        }
        self.parameters = {
            'kernel_size': kernel_size,
            'sigmaX': sigmaX,
            'block_size': block_size,
            'C': C,
            'threshold': threshold,
            'clip_limit': clip_limit,
            'tile_grid_size': tile_grid_size
        }
        self.alpha = 0.1  # Learning rate
        self.gamma = 0.9  # Discount factor
        self.epsilon = 0.1  # Exploration factor

    def choose_action(self, state):
        if np.random.rand() < self.epsilon:
            # Exploration: Randomly choose an action
            return np.random.choice(self.actions['filter']), np.random.choice(self.actions['contrast']), np.random.choice(self.actions['threshold'])
        else:
            # Exploitation: Choose the best action from the Q-table
            return max(self.Q_table.get(state, {}).items(), key=lambda x: x[1])[0]

    def update_Q(self, state, action, reward, next_state):
        best_next_action = max(self.Q_table.get(next_state, {}).items(), key=lambda x: x[1], default=(None, 0))[1]
        current_Q = self.Q_table.get(state, {}).get(action, 0)
        self.Q_table.setdefault(state, {})[action] = current_Q + self.alpha * (reward + self.gamma * best_next_action - current_Q)

    def apply_methods(self, img, filter_type, contrast_type, threshold_type, filter_params, contrast_params, threshold_params):
        if filter_type == 'Gaussien':
            img = Filtrage.apply_Gaussien_filter(img, *filter_params)
        elif filter_type == 'Median':
            img = Filtrage.apply_median_filter(img, *filter_params)
        elif filter_type == 'Mean':
            img = Filtrage.apply_mean_filter(img, *filter_params)

        if contrast_type == 'Equalization':
            img = contrast.adjust_contrast_equalization(img)
        elif contrast_type == 'CLAHE':
            img = contrast.adjust_contrast_clahe(img, *contrast_params)

        if threshold_type == 'Global':
            img = threashold.threshold_global(img, *threshold_params)
        elif threshold_type == 'Local':
            img = threashold.threshold_local(img, *threshold_params)

        return img

    def train(self, img, episodes=100):
        for _ in range(episodes):
            # Choose random parameters for initial state
            state = tuple(np.random.choice(param) for param in self.parameters.values())
            action = self.choose_action(state)
            # Apply the methods with the chosen parameters
            img_new = self.apply_methods(img, *action)
            reward = self.calculate_reward(img_new)  # Define your reward function here
            next_state = tuple(np.random.choice(param) for param in self.parameters.values())
            self.update_Q(state, action, reward, next_state)

    def calculate_reward(self, img):
        # Define how to calculate the reward, for example using SSIM, PSNR, or other image quality metrics
        return np.random.random()  # Placeholder, replace with your reward calculation

# Example parameters
kernel_size = [3, 5, 10]
sigmaX = [0.1, 1.0, 2.0]
block_size = [3, 7, 11]
C = [0.1, 1.0, 2.0]
threshold = [100, 127, 150]
clip_limit = [1, 2, 5]
tile_grid_size = [(3, 3), (5, 5), (7, 7), (11, 11)]

# Initialize Q-learning agent
agent = QLearning(kernel_size, sigmaX, block_size, C, threshold, clip_limit, tile_grid_size)
